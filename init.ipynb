# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If you imported a project with a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# There's no requirements.txt, so nothing to install. This is the case with most projects.

# %%
# %%bash
# # If you have previously installed any packages into this project, we re-install them here to restore your environment.
# if test -f .deepnote/requirements.txt
#   then
#     sed -i '/jupyter/d' .deepnote/requirements.txt
#     pip install -r .deepnote/requirements.txt
#   else echo "Seems like there is nothing to restore. Most likely, you haven't installed any extra packages so far."
# fi
# Out:
# Requirement already satisfied: attrs==19.3.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 1)) (19.3.0)
# Requirement already satisfied: backcall==0.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: bleach==3.1.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 3)) (3.1.5)
# Collecting blis==0.4.1
#   Downloading blis-0.4.1-cp37-cp37m-manylinux1_x86_64.whl (3.7 MB)
# Collecting catalogue==1.0.0
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Requirement already satisfied: certifi==2020.6.20 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 6)) (2020.6.20)
# Requirement already satisfied: chardet==3.0.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 7)) (3.0.4)
# Requirement already satisfied: cycler==0.10.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 8)) (0.10.0)
# Collecting cymem==2.0.3
#   Downloading cymem-2.0.3-cp37-cp37m-manylinux1_x86_64.whl (32 kB)
# Requirement already satisfied: decorator==4.4.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 10)) (4.4.2)
# Requirement already satisfied: defusedxml==0.6.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 11)) (0.6.0)
# Collecting emoji==0.5.4
#   Downloading emoji-0.5.4.tar.gz (43 kB)
# Collecting en-core-web-lg@ https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.3.1/en_core_web_lg-2.3.1.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.3.1/en_core_web_lg-2.3.1.tar.gz (782.7 MB)
# Requirement already satisfied: entrypoints==0.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 14)) (0.3)
# Requirement already satisfied: idna==2.10 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 15)) (2.10)
# Requirement already satisfied: importlib-metadata==1.7.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 16)) (1.7.0)
# Requirement already satisfied: ipykernel==5.3.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 17)) (5.3.1)
# Requirement already satisfied: ipython==7.16.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 18)) (7.16.1)
# Requirement already satisfied: ipython-genutils==0.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 19)) (0.2.0)
# Requirement already satisfied: ipywidgets==7.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 20)) (7.5.1)
# Requirement already satisfied: jedi==0.17.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 21)) (0.17.1)
# Requirement already satisfied: Jinja2==2.11.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 22)) (2.11.2)
# Requirement already satisfied: joblib==0.16.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 23)) (0.16.0)
# Requirement already satisfied: jsonschema==3.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 24)) (3.2.0)
# Requirement already satisfied: kiwisolver==1.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 25)) (1.2.0)
# Requirement already satisfied: MarkupSafe==1.1.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 26)) (1.1.1)
# Requirement already satisfied: matplotlib==3.2.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 27)) (3.2.2)
# Requirement already satisfied: mistune==0.8.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 28)) (0.8.4)
# Collecting murmurhash==1.0.2
#   Downloading murmurhash-1.0.2-cp37-cp37m-manylinux1_x86_64.whl (19 kB)
# Requirement already satisfied: nbconvert==5.6.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 30)) (5.6.1)
# Requirement already satisfied: nbformat==5.0.7 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 31)) (5.0.7)
# Requirement already satisfied: numpy==1.19.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 32)) (1.19.0)
# Requirement already satisfied: packaging==20.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 33)) (20.4)
# Requirement already satisfied: pandas==1.0.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 34)) (1.0.5)
# Requirement already satisfied: pandocfilters==1.4.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 35)) (1.4.2)
# Requirement already satisfied: parso==0.7.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 36)) (0.7.0)
# Requirement already satisfied: pexpect==4.8.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 37)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 38)) (0.7.5)
# Collecting plac==1.1.3
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: pluggy==1.0.0.dev0 in /opt/venv/lib/python3.7/site-packages/pluggy-1.0.0.dev0-py3.7.egg (from -r .deepnote/requirements.txt (line 40)) (1.0.0.dev0)
# Collecting preshed==3.0.2
#   Downloading preshed-3.0.2-cp37-cp37m-manylinux1_x86_64.whl (118 kB)
# Requirement already satisfied: prometheus-client==0.8.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 42)) (0.8.0)
# Requirement already satisfied: prompt-toolkit==3.0.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 43)) (3.0.5)
# Requirement already satisfied: ptyprocess==0.6.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 44)) (0.6.0)
# Requirement already satisfied: Pygments==2.6.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 45)) (2.6.1)
# Requirement already satisfied: pyparsing==2.4.7 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 46)) (2.4.7)
# Requirement already satisfied: pyrsistent==0.16.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 47)) (0.16.0)
# Requirement already satisfied: python-dateutil==2.8.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 48)) (2.8.1)
# Requirement already satisfied: python-jsonrpc-server==0.3.4 in /opt/venv/lib/python3.7/site-packages/python_jsonrpc_server-0.3.4-py3.7.egg (from -r .deepnote/requirements.txt (line 49)) (0.3.4)
# Requirement already satisfied: python-language-server===deepnote-0.02 in /opt/venv/lib/python3.7/site-packages/python_language_server-deepnote_0.02-py3.7.egg (from -r .deepnote/requirements.txt (line 50)) (deepnote-0.02)
# Requirement already satisfied: pytz==2020.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 51)) (2020.1)
# Requirement already satisfied: pyzmq==19.0.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 52)) (19.0.1)
# Requirement already satisfied: requests==2.24.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 53)) (2.24.0)
# Requirement already satisfied: scikit-learn==0.23.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 54)) (0.23.1)
# Requirement already satisfied: scipy==1.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 55)) (1.5.1)
# Requirement already satisfied: Send2Trash==1.5.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 56)) (1.5.0)
# Requirement already satisfied: six==1.15.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 57)) (1.15.0)
# Collecting spacy==2.3.2
#   Downloading spacy-2.3.2-cp37-cp37m-manylinux1_x86_64.whl (9.9 MB)
# Collecting srsly==1.0.2
#   Downloading srsly-1.0.2-cp37-cp37m-manylinux1_x86_64.whl (185 kB)
# Requirement already satisfied: terminado==0.8.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 60)) (0.8.3)
# Requirement already satisfied: testpath==0.4.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 61)) (0.4.4)
# Collecting thinc==7.4.1
#   Downloading thinc-7.4.1-cp37-cp37m-manylinux1_x86_64.whl (2.1 MB)
# Requirement already satisfied: threadpoolctl==2.1.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 63)) (2.1.0)
# Requirement already satisfied: tornado==6.0.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 64)) (6.0.4)
# Collecting tqdm==4.48.0
#   Downloading tqdm-4.48.0-py2.py3-none-any.whl (67 kB)
# Requirement already satisfied: traitlets==4.3.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 66)) (4.3.3)
# Requirement already satisfied: ujson==1.35 in /opt/venv/lib/python3.7/site-packages/ujson-1.35-py3.7-linux-x86_64.egg (from -r .deepnote/requirements.txt (line 67)) (1.35)
# Requirement already satisfied: urllib3==1.25.9 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 68)) (1.25.9)
# Collecting wasabi==0.7.1
#   Downloading wasabi-0.7.1.tar.gz (22 kB)
# Requirement already satisfied: wcwidth==0.2.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 70)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 71)) (0.5.1)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 72)) (3.5.1)
# Requirement already satisfied: zipp==3.1.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 73)) (3.1.0)
# Requirement already satisfied: jupyter-client in /opt/venv/lib/python3.7/site-packages (from ipykernel==5.3.1->-r .deepnote/requirements.txt (line 17)) (6.1.5)
# Requirement already satisfied: setuptools>=18.5 in /opt/venv/lib/python3.7/site-packages (from ipython==7.16.1->-r .deepnote/requirements.txt (line 18)) (47.3.1)
# Requirement already satisfied: jupyter-core in /opt/venv/lib/python3.7/site-packages (from nbconvert==5.6.1->-r .deepnote/requirements.txt (line 30)) (4.6.3)
# Requirement already satisfied: notebook>=4.4.1 in /opt/venv/lib/python3.7/site-packages (from widgetsnbextension==3.5.1->-r .deepnote/requirements.txt (line 72)) (7.0.0.dev0)
# Building wheels for collected packages: emoji, en-core-web-lg, wasabi
#   Building wheel for emoji (setup.py): started
#   Building wheel for emoji (setup.py): finished with status 'done'
#   Created wheel for emoji: filename=emoji-0.5.4-py3-none-any.whl size=42175 sha256=981587cd94cde335a9d7455aa852d76916aebae6375c210590b3610647c61351
#   Stored in directory: /home/jovyan/.cache/pip/wheels/f6/65/82/d742fe456cd8aa21ffe6c4c1eaeedf3c2d430689811bf328e1
#   Building wheel for en-core-web-lg (setup.py): started
#   Building wheel for en-core-web-lg (setup.py): still running...
#   Building wheel for en-core-web-lg (setup.py): finished with status 'done'
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.3.1-py3-none-any.whl size=782936123 sha256=de5263b088c7a56ece8e8a515633f0416abbc6c48531fa6ef1f4baa3f0447184
#   Stored in directory: /home/jovyan/.cache/pip/wheels/41/75/77/c4a98e18b2c317a2a13931cbbea7e3ca7f3a21efc36adc1d71
#   Building wheel for wasabi (setup.py): started
#   Building wheel for wasabi (setup.py): finished with status 'done'
#   Created wheel for wasabi: filename=wasabi-0.7.1-py3-none-any.whl size=20834 sha256=929af16a3b021a53000931dc4a0c639d36f3fb528ea9ae392055a20b3b7bcdb5
#   Stored in directory: /home/jovyan/.cache/pip/wheels/dc/5e/d4/727b6213e9ebec502ff1bf5998f4a83fef87c3aace8a492243
# Successfully built emoji en-core-web-lg wasabi
# Installing collected packages: blis, catalogue, cymem, emoji, murmurhash, preshed, plac, srsly, wasabi, tqdm, thinc, spacy, en-core-web-lg
# Successfully installed blis-0.4.1 catalogue-1.0.0 cymem-2.0.3 emoji-0.5.4 en-core-web-lg-2.3.1 murmurhash-1.0.2 plac-1.1.3 preshed-3.0.2 spacy-2.3.2 srsly-1.0.2 thinc-7.4.1 tqdm-4.48.0 wasabi-0.7.1
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /packages/73/fc/10eeacb926ec1e88cd62f79d9ac106b0a3e3fe5ff1690422d88c29bd0909/murmurhash-1.0.2-cp37-cp37m-manylinux1_x86_64.whl
# WARNING: You are using pip version 20.1.1; however, version 20.2 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If you imported a project with a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Requirement already satisfied: attrs==19.3.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 1)) (19.3.0)
# Requirement already satisfied: backcall==0.2.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: bleach==3.1.5 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 3)) (3.1.5)
# Collecting blis==0.4.1
#   Downloading blis-0.4.1-cp37-cp37m-manylinux1_x86_64.whl (3.7 MB)
# Collecting cairocffi==1.1.0
#   Downloading cairocffi-1.1.0.tar.gz (68 kB)
# Collecting catalogue==1.0.0
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Requirement already satisfied: certifi==2020.6.20 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 7)) (2020.6.20)
# Collecting cffi==1.14.1
#   Downloading cffi-1.14.1-cp37-cp37m-manylinux1_x86_64.whl (401 kB)
# Requirement already satisfied: chardet==3.0.4 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 9)) (3.0.4)
# Requirement already satisfied: cycler==0.10.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 10)) (0.10.0)
# Collecting cymem==2.0.3
#   Downloading cymem-2.0.3-cp37-cp37m-manylinux1_x86_64.whl (32 kB)
# Requirement already satisfied: decorator==4.4.2 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 12)) (4.4.2)
# Requirement already satisfied: defusedxml==0.6.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 13)) (0.6.0)
# Collecting emoji==0.6.0
#   Downloading emoji-0.6.0.tar.gz (51 kB)
# Collecting en-core-web-lg@ https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.3.1/en_core_web_lg-2.3.1.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.3.1/en_core_web_lg-2.3.1.tar.gz (782.7 MB)
# Collecting en-core-web-sm@ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz (12.0 MB)
# Requirement already satisfied: entrypoints==0.3 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 17)) (0.3)
# Requirement already satisfied: idna==2.10 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 18)) (2.10)
# Requirement already satisfied: importlib-metadata==1.7.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 19)) (1.7.0)
# Requirement already satisfied: ipykernel==5.3.1 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 20)) (5.3.1)
# Requirement already satisfied: ipython==7.16.1 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 21)) (7.16.1)
# Requirement already satisfied: ipython-genutils==0.2.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 22)) (0.2.0)
# Requirement already satisfied: ipywidgets==7.5.1 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 23)) (7.5.1)
# Requirement already satisfied: Jinja2==2.11.2 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 24)) (2.11.2)
# Requirement already satisfied: joblib==0.16.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 25)) (0.16.0)
# Requirement already satisfied: jsonschema==3.2.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 26)) (3.2.0)
# Requirement already satisfied: kiwisolver==1.2.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 27)) (1.2.0)
# Requirement already satisfied: MarkupSafe==1.1.1 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 28)) (1.1.1)
# Requirement already satisfied: matplotlib==3.2.2 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 29)) (3.2.2)
# Requirement already satisfied: mistune==0.8.4 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 30)) (0.8.4)
# Collecting murmurhash==1.0.2
#   Downloading murmurhash-1.0.2-cp37-cp37m-manylinux1_x86_64.whl (19 kB)
# Requirement already satisfied: nbconvert==5.6.1 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 32)) (5.6.1)
# Requirement already satisfied: nbformat==5.0.7 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 33)) (5.0.7)
# Requirement already satisfied: numpy==1.19.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 34)) (1.19.0)
# Collecting oauthlib==3.1.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Requirement already satisfied: packaging==20.4 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 36)) (20.4)
# Requirement already satisfied: pandas==1.0.5 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 37)) (1.0.5)
# Requirement already satisfied: pandocfilters==1.4.2 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 38)) (1.4.2)
# Requirement already satisfied: parso==0.7.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 39)) (0.7.0)
# Requirement already satisfied: pexpect==4.8.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 40)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 41)) (0.7.5)
# Collecting plac==1.1.3
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: pluggy==1.0.0.dev0 in /opt/venv/lib/python3.7/site-packages/pluggy-1.0.0.dev0-py3.7.egg (from -r ./requirements.txt (line 43)) (1.0.0.dev0)
# Collecting preshed==3.0.2
#   Downloading preshed-3.0.2-cp37-cp37m-manylinux1_x86_64.whl (118 kB)
# Requirement already satisfied: prometheus-client==0.8.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 45)) (0.8.0)
# Requirement already satisfied: prompt-toolkit==3.0.5 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 46)) (3.0.5)
# Requirement already satisfied: ptyprocess==0.6.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 47)) (0.6.0)
# Collecting pycparser==2.20
#   Using cached pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: Pygments==2.6.1 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 49)) (2.6.1)
# Requirement already satisfied: pyparsing==2.4.7 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 50)) (2.4.7)
# Requirement already satisfied: pyrsistent==0.16.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 51)) (0.16.0)
# Requirement already satisfied: python-dateutil==2.8.1 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 52)) (2.8.1)
# Collecting python-igraph==0.8.2
#   Downloading python_igraph-0.8.2-cp37-cp37m-manylinux2010_x86_64.whl (3.2 MB)
# Requirement already satisfied: python-jsonrpc-server==0.3.4 in /opt/venv/lib/python3.7/site-packages/python_jsonrpc_server-0.3.4-py3.7.egg (from -r ./requirements.txt (line 54)) (0.3.4)
# Requirement already satisfied: python-language-server===deepnote-0.02 in /opt/venv/lib/python3.7/site-packages/python_language_server-deepnote_0.02-py3.7.egg (from -r ./requirements.txt (line 55)) (deepnote-0.02)
# Requirement already satisfied: pytz==2020.1 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 56)) (2020.1)
# Requirement already satisfied: pyzmq==19.0.1 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 57)) (19.0.1)
# Requirement already satisfied: requests==2.24.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 58)) (2.24.0)
# Collecting requests-oauthlib==1.3.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: scikit-learn==0.23.1 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 60)) (0.23.1)
# Requirement already satisfied: scipy==1.5.1 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 61)) (1.5.1)
# Requirement already satisfied: Send2Trash==1.5.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 62)) (1.5.0)
# Requirement already satisfied: six==1.15.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 63)) (1.15.0)
# Collecting spacy==2.3.2
#   Downloading spacy-2.3.2-cp37-cp37m-manylinux1_x86_64.whl (9.9 MB)
# Collecting srsly==1.0.2
#   Downloading srsly-1.0.2-cp37-cp37m-manylinux1_x86_64.whl (185 kB)
# Requirement already satisfied: terminado==0.8.3 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 66)) (0.8.3)
# Requirement already satisfied: testpath==0.4.4 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 67)) (0.4.4)
# Collecting texttable==1.6.2
#   Downloading texttable-1.6.2-py2.py3-none-any.whl (10 kB)
# Collecting thinc==7.4.1
#   Downloading thinc-7.4.1-cp37-cp37m-manylinux1_x86_64.whl (2.1 MB)
# Requirement already satisfied: threadpoolctl==2.1.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 70)) (2.1.0)
# Requirement already satisfied: tornado==6.0.4 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 71)) (6.0.4)
# Collecting tqdm==4.48.0
#   Downloading tqdm-4.48.0-py2.py3-none-any.whl (67 kB)
# Requirement already satisfied: traitlets==4.3.3 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 73)) (4.3.3)
# Collecting tweepy==3.9.0
#   Downloading tweepy-3.9.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: ujson==1.35 in /opt/venv/lib/python3.7/site-packages/ujson-1.35-py3.7-linux-x86_64.egg (from -r ./requirements.txt (line 75)) (1.35)
# Requirement already satisfied: urllib3==1.25.9 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 76)) (1.25.9)
# Collecting wasabi==0.7.1
#   Downloading wasabi-0.7.1.tar.gz (22 kB)
# Requirement already satisfied: wcwidth==0.2.5 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 78)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 79)) (0.5.1)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 80)) (3.5.1)
# Requirement already satisfied: zipp==3.1.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 81)) (3.1.0)
# Requirement already satisfied: setuptools>=39.2.0 in /opt/venv/lib/python3.7/site-packages (from cairocffi==1.1.0->-r ./requirements.txt (line 5)) (47.3.1)
# Requirement already satisfied: jupyter-client in /opt/venv/lib/python3.7/site-packages (from ipykernel==5.3.1->-r ./requirements.txt (line 20)) (6.1.5)
# Requirement already satisfied: jedi>=0.10 in /opt/venv/lib/python3.7/site-packages (from ipython==7.16.1->-r ./requirements.txt (line 21)) (0.17.1)
# Requirement already satisfied: jupyter-core in /opt/venv/lib/python3.7/site-packages (from nbconvert==5.6.1->-r ./requirements.txt (line 32)) (4.6.3)
# Requirement already satisfied: notebook>=4.4.1 in /opt/venv/lib/python3.7/site-packages (from widgetsnbextension==3.5.1->-r ./requirements.txt (line 80)) (7.0.0.dev0)
# Building wheels for collected packages: cairocffi, emoji, en-core-web-lg, en-core-web-sm, wasabi
#   Building wheel for cairocffi (setup.py): started
#   Building wheel for cairocffi (setup.py): finished with status 'done'
#   Created wheel for cairocffi: filename=cairocffi-1.1.0-py3-none-any.whl size=88588 sha256=572a3a48436f34589cebdcd9061149049f2ba680f8100a23a4654f97bc2ff85b
#   Stored in directory: /home/jovyan/.cache/pip/wheels/04/7d/d9/68956b3da44dbef65b150faff8a9810209588de332ebe1fa63
#   Building wheel for emoji (setup.py): started
#   Building wheel for emoji (setup.py): finished with status 'done'
#   Created wheel for emoji: filename=emoji-0.6.0-py3-none-any.whl size=49714 sha256=9bf0b9bb797ba28076054e8f701aeb582d87da4b224116aa048f593b229cb0f1
#   Stored in directory: /home/jovyan/.cache/pip/wheels/4e/bf/6b/2e22b3708d14bf6384f862db539b044d6931bd6b14ad3c9adc
#   Building wheel for en-core-web-lg (setup.py): started
#   Building wheel for en-core-web-lg (setup.py): still running...
#   Building wheel for en-core-web-lg (setup.py): finished with status 'done'
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.3.1-py3-none-any.whl size=782936123 sha256=595202b5a982c3b3e8e7372246969144472e115e28cb59c0e8beafea98c7ad0d
#   Stored in directory: /home/jovyan/.cache/pip/wheels/41/75/77/c4a98e18b2c317a2a13931cbbea7e3ca7f3a21efc36adc1d71
#   Building wheel for en-core-web-sm (setup.py): started
#   Building wheel for en-core-web-sm (setup.py): finished with status 'done'
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.3.1-py3-none-any.whl size=12047105 sha256=02510028b953964de8e5527a4a7967787171bb7890efd97b9df44d9029a63010
#   Stored in directory: /home/jovyan/.cache/pip/wheels/b7/0d/f0/7ecae8427c515065d75410989e15e5785dd3975fe06e795cd9
#   Building wheel for wasabi (setup.py): started
#   Building wheel for wasabi (setup.py): finished with status 'done'
#   Created wheel for wasabi: filename=wasabi-0.7.1-py3-none-any.whl size=20834 sha256=6de9a98b4d93c5187167b56bd996aca62e4588bb924ca45391e7271f669a766d
#   Stored in directory: /home/jovyan/.cache/pip/wheels/dc/5e/d4/727b6213e9ebec502ff1bf5998f4a83fef87c3aace8a492243
# Successfully built cairocffi emoji en-core-web-lg en-core-web-sm wasabi
# Installing collected packages: blis, pycparser, cffi, cairocffi, catalogue, cymem, emoji, wasabi, plac, murmurhash, preshed, srsly, tqdm, thinc, spacy, en-core-web-lg, en-core-web-sm, oauthlib, texttable, python-igraph, requests-oauthlib, tweepy
# Successfully installed blis-0.4.1 cairocffi-1.1.0 catalogue-1.0.0 cffi-1.14.1 cymem-2.0.3 emoji-0.6.0 en-core-web-lg-2.3.1 en-core-web-sm-2.3.1 murmurhash-1.0.2 oauthlib-3.1.0 plac-1.1.3 preshed-3.0.2 pycparser-2.20 python-igraph-0.8.2 requests-oauthlib-1.3.0 spacy-2.3.2 srsly-1.0.2 texttable-1.6.2 thinc-7.4.1 tqdm-4.48.0 tweepy-3.9.0 wasabi-0.7.1
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.

# %%
# %%bash
# # If you have previously installed any packages into this project, we re-install them here to restore your environment.
# if test -f .deepnote/requirements.txt
#   then
#     sed -i '/jupyter/d' .deepnote/requirements.txt
#     pip install -r .deepnote/requirements.txt
#   else echo "Seems like there is nothing to restore. Most likely, you haven't installed any extra packages so far."
# fi
# Out:
# Requirement already satisfied: attrs==19.3.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 1)) (19.3.0)
# Requirement already satisfied: backcall==0.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: bleach==3.1.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 3)) (3.1.5)
# Requirement already satisfied: blis==0.4.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 4)) (0.4.1)
# Collecting cachetools==4.1.1
#   Downloading cachetools-4.1.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: cairocffi==1.1.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: catalogue==1.0.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 7)) (1.0.0)
# Requirement already satisfied: certifi==2020.6.20 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 8)) (2020.6.20)
# Requirement already satisfied: cffi==1.14.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 9)) (1.14.1)
# Requirement already satisfied: chardet==3.0.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 10)) (3.0.4)
# Collecting cssselect==1.1.0
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: cycler==0.10.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 12)) (0.10.0)
# Requirement already satisfied: cymem==2.0.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 13)) (2.0.3)
# Requirement already satisfied: decorator==4.4.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 14)) (4.4.2)
# Requirement already satisfied: defusedxml==0.6.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 15)) (0.6.0)
# Requirement already satisfied: emoji==0.6.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 16)) (0.6.0)
# Requirement already satisfied: en-core-web-lg@ https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.3.1/en_core_web_lg-2.3.1.tar.gz from https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.3.1/en_core_web_lg-2.3.1.tar.gz in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 17)) (2.3.1)
# Requirement already satisfied: en-core-web-sm@ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 18)) (2.3.1)
# Requirement already satisfied: entrypoints==0.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 19)) (0.3)
# Collecting GetOldTweets3==0.0.11
#   Downloading GetOldTweets3-0.0.11-py3-none-any.whl (13 kB)
# Collecting google-api-core==1.22.1
#   Downloading google_api_core-1.22.1-py2.py3-none-any.whl (91 kB)
# Collecting google-api-python-client==1.10.0
#   Downloading google_api_python_client-1.10.0-py2.py3-none-any.whl (60 kB)
# Collecting google-auth==1.20.1
#   Downloading google_auth-1.20.1-py2.py3-none-any.whl (91 kB)
# Collecting google-auth-httplib2==0.0.4
#   Downloading google_auth_httplib2-0.0.4-py2.py3-none-any.whl (9.1 kB)
# Collecting googleapis-common-protos==1.52.0
#   Downloading googleapis_common_protos-1.52.0-py2.py3-none-any.whl (100 kB)
# Collecting httplib2==0.18.1
#   Downloading httplib2-0.18.1-py3-none-any.whl (95 kB)
# Requirement already satisfied: idna==2.10 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 27)) (2.10)
# Requirement already satisfied: importlib-metadata==1.7.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 28)) (1.7.0)
# Requirement already satisfied: ipykernel==5.3.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 29)) (5.3.1)
# Requirement already satisfied: ipython==7.16.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 30)) (7.16.1)
# Requirement already satisfied: ipython-genutils==0.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 31)) (0.2.0)
# Requirement already satisfied: ipywidgets==7.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 32)) (7.5.1)
# Requirement already satisfied: jedi==0.17.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 33)) (0.17.1)
# Requirement already satisfied: Jinja2==2.11.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 34)) (2.11.2)
# Requirement already satisfied: joblib==0.16.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 35)) (0.16.0)
# Requirement already satisfied: jsonschema==3.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 36)) (3.2.0)
# Requirement already satisfied: kiwisolver==1.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 37)) (1.2.0)
# Collecting lxml==4.5.2
#   Downloading lxml-4.5.2-cp37-cp37m-manylinux1_x86_64.whl (5.5 MB)
# Requirement already satisfied: MarkupSafe==1.1.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 39)) (1.1.1)
# Requirement already satisfied: matplotlib==3.2.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 40)) (3.2.2)
# Requirement already satisfied: mistune==0.8.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 41)) (0.8.4)
# Requirement already satisfied: murmurhash==1.0.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 42)) (1.0.2)
# Requirement already satisfied: nbconvert==5.6.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 43)) (5.6.1)
# Requirement already satisfied: nbformat==5.0.7 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 44)) (5.0.7)
# Requirement already satisfied: numpy==1.19.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 45)) (1.19.0)
# Collecting oauth2client==4.1.3
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# Requirement already satisfied: oauthlib==3.1.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 47)) (3.1.0)
# Requirement already satisfied: packaging==20.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 48)) (20.4)
# Requirement already satisfied: pandas==1.0.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 49)) (1.0.5)
# Requirement already satisfied: pandocfilters==1.4.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 50)) (1.4.2)
# Requirement already satisfied: parso==0.7.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 51)) (0.7.0)
# Requirement already satisfied: pexpect==4.8.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 52)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 53)) (0.7.5)
# Requirement already satisfied: plac==1.1.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 54)) (1.1.3)
# Requirement already satisfied: pluggy==1.0.0.dev0 in /opt/venv/lib/python3.7/site-packages/pluggy-1.0.0.dev0-py3.7.egg (from -r .deepnote/requirements.txt (line 55)) (1.0.0.dev0)
# Requirement already satisfied: preshed==3.0.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 56)) (3.0.2)
# Requirement already satisfied: prometheus-client==0.8.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 57)) (0.8.0)
# Requirement already satisfied: prompt-toolkit==3.0.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 58)) (3.0.5)
# Collecting protobuf==3.12.4
#   Downloading protobuf-3.12.4-cp37-cp37m-manylinux1_x86_64.whl (1.3 MB)
# Requirement already satisfied: ptyprocess==0.6.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 60)) (0.6.0)
# Collecting pyasn1==0.4.8
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting pyasn1-modules==0.2.8
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Requirement already satisfied: pycparser==2.20 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 63)) (2.20)
# Collecting PyDrive==1.3.1
#   Downloading PyDrive-1.3.1.tar.gz (987 kB)
# Requirement already satisfied: Pygments==2.6.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 65)) (2.6.1)
# Requirement already satisfied: pyparsing==2.4.7 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 66)) (2.4.7)
# Collecting pyquery==1.4.1
#   Downloading pyquery-1.4.1-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: pyrsistent==0.16.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 68)) (0.16.0)
# Collecting PySocks==1.7.1
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: python-dateutil==2.8.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 70)) (2.8.1)
# Requirement already satisfied: python-igraph==0.8.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 71)) (0.8.2)
# Requirement already satisfied: python-jsonrpc-server==0.3.4 in /opt/venv/lib/python3.7/site-packages/python_jsonrpc_server-0.3.4-py3.7.egg (from -r .deepnote/requirements.txt (line 72)) (0.3.4)
# Requirement already satisfied: python-language-server===deepnote-0.02 in /opt/venv/lib/python3.7/site-packages/python_language_server-deepnote_0.02-py3.7.egg (from -r .deepnote/requirements.txt (line 73)) (deepnote-0.02)
# Requirement already satisfied: pytz==2020.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 74)) (2020.1)
# Collecting PyYAML==5.3.1
#   Downloading PyYAML-5.3.1.tar.gz (269 kB)
# Requirement already satisfied: pyzmq==19.0.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 76)) (19.0.1)
# Requirement already satisfied: requests==2.24.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 77)) (2.24.0)
# Requirement already satisfied: requests-oauthlib==1.3.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 78)) (1.3.0)
# Collecting rsa==4.6
#   Downloading rsa-4.6-py3-none-any.whl (47 kB)
# Requirement already satisfied: scikit-learn==0.23.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 80)) (0.23.1)
# Requirement already satisfied: scipy==1.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 81)) (1.5.1)
# Requirement already satisfied: Send2Trash==1.5.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 82)) (1.5.0)
# Requirement already satisfied: six==1.15.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 83)) (1.15.0)
# Requirement already satisfied: spacy==2.3.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 84)) (2.3.2)
# Requirement already satisfied: srsly==1.0.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 85)) (1.0.2)
# Requirement already satisfied: terminado==0.8.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 86)) (0.8.3)
# Requirement already satisfied: testpath==0.4.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 87)) (0.4.4)
# Requirement already satisfied: texttable==1.6.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 88)) (1.6.2)
# Requirement already satisfied: thinc==7.4.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 89)) (7.4.1)
# Requirement already satisfied: threadpoolctl==2.1.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 90)) (2.1.0)
# Requirement already satisfied: tornado==6.0.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 91)) (6.0.4)
# Requirement already satisfied: tqdm==4.48.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 92)) (4.48.0)
# Requirement already satisfied: traitlets==4.3.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 93)) (4.3.3)
# Requirement already satisfied: tweepy==3.9.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 94)) (3.9.0)
# Requirement already satisfied: ujson==1.35 in /opt/venv/lib/python3.7/site-packages/ujson-1.35-py3.7-linux-x86_64.egg (from -r .deepnote/requirements.txt (line 95)) (1.35)
# Collecting uritemplate==3.0.1
#   Downloading uritemplate-3.0.1-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: urllib3==1.25.9 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 97)) (1.25.9)
# Requirement already satisfied: wasabi==0.7.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 98)) (0.7.1)
# Requirement already satisfied: wcwidth==0.2.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 99)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 100)) (0.5.1)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 101)) (3.5.1)
# Requirement already satisfied: zipp==3.1.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 102)) (3.1.0)
# Requirement already satisfied: setuptools>=39.2.0 in /opt/venv/lib/python3.7/site-packages (from cairocffi==1.1.0->-r .deepnote/requirements.txt (line 6)) (47.3.1)
# Requirement already satisfied: jupyter-client in /opt/venv/lib/python3.7/site-packages (from ipykernel==5.3.1->-r .deepnote/requirements.txt (line 29)) (6.1.5)
# Requirement already satisfied: jupyter-core in /opt/venv/lib/python3.7/site-packages (from nbconvert==5.6.1->-r .deepnote/requirements.txt (line 43)) (4.6.3)
# Requirement already satisfied: notebook>=4.4.1 in /opt/venv/lib/python3.7/site-packages (from widgetsnbextension==3.5.1->-r .deepnote/requirements.txt (line 101)) (7.0.0.dev0)
# Building wheels for collected packages: PyDrive, PyYAML
#   Building wheel for PyDrive (setup.py): started
#   Building wheel for PyDrive (setup.py): finished with status 'done'
#   Created wheel for PyDrive: filename=PyDrive-1.3.1-py3-none-any.whl size=27435 sha256=3338dc6771481b04439fe6aa0655e3c9949db44a5498caf3fdb3eb1122af3a3e
#   Stored in directory: /home/jovyan/.cache/pip/wheels/57/cc/07/6aac75f5395a224650905accd38c868c2276782a56f1046b7b
#   Building wheel for PyYAML (setup.py): started
#   Building wheel for PyYAML (setup.py): finished with status 'done'
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44619 sha256=1146d77b0ef4a405aeaba24975a49c706b6cf96dc99b44fc647fc09a239eb549
#   Stored in directory: /home/jovyan/.cache/pip/wheels/5e/03/1e/e1e954795d6f35dfc7b637fe2277bff021303bd9570ecea653
# Successfully built PyDrive PyYAML
# Installing collected packages: cachetools, cssselect, lxml, pyquery, GetOldTweets3, protobuf, googleapis-common-protos, pyasn1, pyasn1-modules, rsa, google-auth, google-api-core, uritemplate, httplib2, google-auth-httplib2, google-api-python-client, oauth2client, PyYAML, PyDrive, PySocks
# Successfully installed GetOldTweets3-0.0.11 PyDrive-1.3.1 PySocks-1.7.1 PyYAML-5.3.1 cachetools-4.1.1 cssselect-1.1.0 google-api-core-1.22.1 google-api-python-client-1.10.0 google-auth-1.20.1 google-auth-httplib2-0.0.4 googleapis-common-protos-1.52.0 httplib2-0.18.1 lxml-4.5.2 oauth2client-4.1.3 protobuf-3.12.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 pyquery-1.4.1 rsa-4.6 uritemplate-3.0.1
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.

# %%
import pandas as pd

data = pd.read_csv('new_game/data.csv')

lister = data['hashtags']

from collections import Counter
Counter(lister)
# Out:
# Counter({nan: 2400,
#          '#GA09': 1,
#          '#MNSEN': 1,
#          '#MN06': 1,
#          '#MN08': 1,
#          '#MN01': 1,
#          '#MOGOV': 1,
#          '#MN07': 1,
#          '#WeWantToPlay': 1,
#          '#MAGA': 33,
#          '#TN04': 1,
#          '#SemperFidelis': 1,
#          '#HR1957': 1,
#          '#MO03': 1,
#          '#MO04': 1,
#          '#MO06': 1,
#          '#MO07': 1,
#          '#WA04': 1,
#          '#WA05': 1,
#          '#MO08': 1,
#          '#LESM': 2,
#          '#RIGGEDELECTION': 1,
#          '#CARESAct': 4,
#          '#StopExecutionsInIran': 1,
#          '#MAGA2020': 4,
#          '#RIPCharlieDaniels': 1,
#          '#SaluteToAmerica': 1,
#          '#MAGA #AZ04': 1,
#          '#TX23': 1,
#          '#OH13': 1,
#          '#TX13 #MAGA': 2,
#          '#2A #UT04': 1,
#          '#Salute2America': 1,
#          '#SchoolChoice': 1,
#          '#2A #COSEN': 1,
#          '#MAGA #2A #CO03': 1,
#          '#JUSTICEAct': 1,
# ...

# %%
lister = data['mentions']

from collections import Counter
Counter(lister).most_common()
# Out:
# [(nan, 1942),
#  ('@FoxNews', 29),
#  ('@CNN', 17),
#  ('@USDOT', 16),
#  ('@foxandfriends', 16),
#  ('@nytimes', 13),
#  ('@BreitbartNews', 9),
#  ('@seanhannity @FoxNews', 8),
#  ('@OANN', 7),
#  ('@seanhannity', 6),
#  ('@nytimes @washingtonpost', 6),
#  ('@RonnyJackson4TX', 5),
#  ('@LouDobbs', 5),
#  ('@CDCgov', 5),
#  ('@SenatorTimScott', 5),
#  ('@MariaBartiromo', 4),
#  ('@WhiteHouse', 4),
#  ('@SenateGOP', 4),
#  ('@TomTiffanyWI', 4),
#  ('@WSJ', 3),
#  ('@FLOTUS', 3),
#  ('@Judgenap @foxandfriends', 3),
#  ('@TTuberville', 3),
#  ('@TuckerCarlson @FoxNews', 3),
#  ('@kilmeade @foxandfriends', 3),
#  ('@VanDrewForNJ', 3),
#  ('@CNN @FoxNews', 3),
#  ('@NYCMayor', 3),
#  ('@foxandfriends @CNN', 3),
#  ('@MayorBowser', 3),
#  ('@JacobsNY27', 3),
#  ('@SecretService', 3),
#  ('@IngrahamAngle @FoxNews', 3),
#  ('@fema', 3),
#  ('@narendramodi', 3),
#  ('@MikeGarcia2020 @ChristyforCA25', 3),
#  ('@honeywell', 3),
#  ('@VP', 3),
#  ('@KamalaHarris', 2),
#  ('@TuckerCarlson', 2),
# ...
